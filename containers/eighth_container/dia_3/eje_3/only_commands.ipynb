# %%
# %%bash
# kubectl delete configmap procesador-config --from-file=procesador.py
# Out:
# error: unknown flag: --from-file
# See 'kubectl delete --help' for usage.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'kubectl delete configmap procesador-config --from-file=procesador.py\n')
#
# File ~/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%bash
# kubectl create configmap procesador-config --from-file=procesador.py
# Out:
# error: failed to create configmap: configmaps "procesador-config" already exists
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'kubectl create configmap procesador-config --from-file=procesador.py\n')
#
# File ~/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%bash
# kubectl create configmap procesador-config --from-file=procesador.py
# Out:
# error: failed to create configmap: configmaps "procesador-config" already exists
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'kubectl create configmap procesador-config --from-file=procesador.py\n')
#
# File ~/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%bash
# kubectl delete -f job_eficiente.yaml
# Out:
# job.batch "job-eficiente-batch" deleted

# %%
# %%bash
# kubectl apply -f job_eficiente.yaml
# Out:
# job.batch/job-eficiente-batch created

# %%
# !kubectl get jobs
# Out:
# NAME                   COMPLETIONS   DURATION   AGE
# batch-job-inicial      1/1           14s        3d6h
# batch-telemetria-job   1/1           7s         3d4h
# job-eficiente-batch    0/1           3s         3s
# job-pathlib-batch      1/1           9s         29h

# %%
# !kubectl get pods
# Out:
# NAME                         READY   STATUS      RESTARTS   AGE
# batch-job-inicial-jw2pf      0/1     Completed   0          3d6h
# batch-telemetria-job-kpjbv   0/1     Completed   0          3d4h
# job-eficiente-batch-429qr    1/1     Running     0          7s
# job-pathlib-batch-5cgd9      0/1     Completed   0          29h
# python-batch-pod             0/1     Completed   0          3d3h

# %%
# !kubectl logs job-eficiente-batch-429qr
# Out:
# === INICIANDO PROCESADOR FRUGAL [Produccion-Costos-Bajos] ===
# Preparando la carga de 1000 registros...
# Mapeando uso de memoria asignada por Kubernetes...
#  -> Procesando bloque 1/4... [Memoria Estable]
#  -> Procesando bloque 2/4... [Memoria Estable]
#  -> Procesando bloque 3/4... [Memoria Estable]
#  -> Procesando bloque 4/4... [Memoria Estable]
# ✅ Balance de recursos óptimo. Registros procesados con éxito.
# === CIERRE DE CONTENEDOR EFICIENTE ===

# %%
# !kubectl describe pod job-eficiente-batch-429qr
# Out:
# Name:             job-eficiente-batch-429qr
# Namespace:        default
# Priority:         0
# Service Account:  default
# Node:             docker-desktop/192.168.65.4
# Start Time:       Tue, 07 Jul 2026 21:07:00 -0700
# Labels:           component=architect-python-batch
#                   controller-uid=04fe70fa-d25b-4ba4-b48e-23fa4d1d78a6
#                   job-name=job-eficiente-batch
#                   layer=exercise-4
# Annotations:      <none>
# Status:           Succeeded
# IP:               10.1.0.132
# IPs:
#   IP:           10.1.0.132
# Controlled By:  Job/job-eficiente-batch
# Containers:
#   python-worker:
#     Container ID:  docker://0d6af0662fd786edfa980c5a66d66d2a0e7942c722c3fb831e678aff479d6265
#     Image:         python:3.10-slim
#     Image ID:      docker-pullable://python@sha256:5f9928ea39771e8ddf4fb9a96ab24f65f087793635614405a1dc9384f040852e
#     Port:          <none>
#     Host Port:     <none>
#     Command:
#       python
#       /app/procesador.py
# ...

# %% [raw]
# Paso 2: De Tarea Única a Automatización Real (El CronJob)
# Hasta ahora has aprendido a crear un Job eficiente (una jaula controlada para una sola ejecución). Pero en el mundo real de la empresa, nadie quiere estar apretando un botón manualmente para procesar registros todos los días.
#
# Aquí es donde entra el Segundo Paso: convertir nuestro plano en un CronJob (un planificador temporal automatizado).
#
# He generado la siguiente lección en tu editor para que diseñemos esta automatización paso a paso.
# Lección 2: Automatización con CronJobs
# Jul 6, 6:39 PM
#
# Ejecuta el comando de limpieza y avísame cuando estés listo para que creemos el archivo cronjob_eficiente.yaml en tu Jupyter. ¡Vamos con todo!

# %%
# !pwd
# Out:
# /Users/admin/Desktop/Shafer_Python_Classes/Cloud_engineering_practice/containers/ninth_container/repaso

# %%
# !ls
# Out:
# Dockerfile       next_2           next_6           requirements.txt
# Untitled.ipynb   next_3           next_7           tests
# app.py           next_4           next_8
# next_1           next_5           next_9

# %%
# !mkdir -p next_10/data/archive/input next_10/data/archive/output

# %%
from flask import Flask
import boto3
from moto import mock_aws
from pathlib import Path  # <-- Cambiado al estándar moderno
 d
app = Flask(__name__)

mock = mock_aws()
mock.start()

s3 = boto3.client("s3", region_name="us-east-1")
BUCKET_NAME = "vehicle-diagnostic-vault"
s3.create_bucket(Bucket=BUCKET_NAME)

s3.put_object(
    Bucket=BUCKET_NAME,
    Key="live_fault_code.txt",
    Body="🚨 CLOUD DATA: P0171 - System Too Lean (Bank 1)"
)

@app.route("/")
def home():
    return '''
    <h1>🌐 Diagnostic Web Portal Active</h1>
    <p>Welcome to the main station terminal.</p>
    <hr>
    <a href="/diagnostics" style="padding: 10px 15px; background-color: #007bff; color: white; text-decoration: none; border-radius: 5px; font-family: sans-serif;">
        🚀 Launch System Diagnostics Scanner
    </a>
    '''

@app.route("/diagnostics")
def diagnostics():
    response = s3.get_object(Bucket=BUCKET_NAME, Key="live_fault_code.txt")
    cloud_data = response["Body"].read().decode("utf-8")
     
    # 🎯 SOLUCIÓN CLOUD DINÁMICA: Encuentra la ruta local actual de forma inteligente
    BASE_DIR = Path.cwd()
    output_dir = BASE_DIR / "output"
    output_filepath = output_dir / "live_fault_code.txt"
    
    # Pathlib crea la estructura de forma segura sin importar el Sistema Operativo
    output_dir.mkdir(parents=True, exist_ok=True)
        
    with open(output_filepath, "w", encoding="utf-8") as f:
        f.write(cloud_data)
        
    return f'''
    <h2>📊 System Scan Live Feed</h2>
    <div style="padding: 15px; background-color: #e2f0d9; color: #385723; border: 1px solid #c5e0b4; border-radius: 5px; font-family: monospace; font-size: 1.1em; margin-bottom: 15px;">
        ✅ <strong>Cloud Match Verification:</strong> Connected to mock S3 bucket successfully.
    </div>
    <div style="padding: 15px; background-color: #f8d7da; color: #721c24; border: 1px solid #f5c6cb; border-radius: 5px; font-family: monospace; font-size: 1.2em;">
        {cloud_data}
    </div>
    <p style="color: #2e75b6; font-family: sans-serif; font-weight: bold;">
        💾 Local Host Sync: Copy written to path '{output_filepath}'
    </p>
    <br>
    <a href="/" style="color: #6c757d; font-family: sans-serif;">⬅️ Return to Main Terminal</a>
    '''

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.20.10.3:5000
# Press CTRL+C to quit
# 172.20.10.3 - - [25/Jun/2026 10:59:03] "GET / HTTP/1.1" 200 -
# 172.20.10.3 - - [25/Jun/2026 10:59:07] "GET /diagnostics HTTP/1.1" 200 -
# 172.20.10.3 - - [25/Jun/2026 11:00:29] "GET / HTTP/1.1" 200 -
# 172.20.10.3 - - [25/Jun/2026 11:00:31] "GET /diagnostics HTTP/1.1" 200 -
# 172.20.10.3 - - [25/Jun/2026 11:00:33] "GET / HTTP/1.1" 200 -
# 172.20.10.3 - - [25/Jun/2026 11:00:34] "GET /diagnostics HTTP/1.1" 200 -
# 172.20.10.3 - - [25/Jun/2026 11:00:35] "GET / HTTP/1.1" 200 -
# 172.20.10.3 - - [25/Jun/2026 11:00:37] "GET /diagnostics HTTP/1.1" 200 -

# %%
# vehicle-fault-pipeline

# %%
# Define the raw inventory tools for our data pipeline
requirements_content = """Flask==3.0.0
boto3>=1.34.0
moto[s3]>=5.0.0
"""

# Open a file handle and write the contents cleanly to disk
with open("requirements.txt", "w") as f:
    f.write(requirements_content)

print("📦 Success! Created your conventional requirements.txt tool inventory!")
# Out:
# 📦 Success! Created your conventional requirements.txt tool inventory!

# %% [raw]
# # Wrap the app.py payload cleanly into a string variable
# app_payload = """from flask import Flask
# import boto3
# from moto import mock_aws
# import os
#
# app = Flask(__name__)
#
# mock = mock_aws()
# mock.start()
#
# s3 = boto3.client("s3", region_name="us-east-1")
# BUCKET_NAME = "vehicle-diagnostic-vault"
# s3.create_bucket(Bucket=BUCKET_NAME)
#
# s3.put_object(
#     Bucket=BUCKET_NAME,
#     Key="live_fault_code.txt",
#     Body="🚨 CLOUD DATA: P0171 - System Too Lean (Bank 1)"
# )
#
# @app.route("/")
# def home():
#     return \"\"\"
#     <h1>🌐 Diagnostic Web Portal Active</h1>
#     <p>Welcome to the main station terminal.</p>
#     <hr>
#     <a href="/diagnostics" style="padding: 10px 15px; background-color: #007bff; color: white; text-decoration: none; border-radius: 5px; font-family: sans-serif;">
#         🚀 Launch System Diagnostics Scanner
#     </a>
#     \"\"\"
#
# @app.route("/diagnostics")
# def diagnostics():
#     response = s3.get_object(Bucket=BUCKET_NAME, Key="live_fault_code.txt")
#     cloud_data = response["Body"].read().decode("utf-8")
#
#     output_dir = "/app/output"
#     output_filepath = os.path.abspath(os.path.join(output_dir, "live_fault_code.txt"))
#     # target_filepath = os.path.abspath(os.path.join(log_dir, filename))
#
#     if not os.path.exists(output_dir):
#         os.makedirs(output_dir)
#
#     with open(output_filepath, "w") as f:
#         f.write(cloud_data)
#
#     return f\"\"\"
#     <h2>📊 System Scan Live Feed</h2>
#     <div style="padding: 15px; background-color: #e2f0d9; color: #385723; border: 1px solid #c5e0b4; border-radius: 5px; font-family: monospace; font-size: 1.1em; margin-bottom: 15px;">
#         ✅ <strong>Cloud Match Verification:</strong> Connected to mock S3 bucket successfully.
#     </div>
#     <div style="padding: 15px; background-color: #f8d7da; color: #721c24; border: 1px solid #f5c6cb; border-radius: 5px; font-family: monospace; font-size: 1.2em;">
#         {cloud_data}
#     </div>
#     <p style="color: #2e75b6; font-family: sans-serif; font-weight: bold;">
#         💾 Local Host Sync: Copy written to container path '{output_filepath}'
#     </p>
#     <br>
#     <a href="/" style="color: #6c757d; font-family: sans-serif;">⬅️ Return to Main Terminal</a>
#     \"\"\"
#
# if __name__ == "__main__":
#     app.run(host="0.0.0.0", port=5000)
# """
#
# # Write the payload out as a python file on your laptop hard drive
# with open("app.py", "w") as f:
#     f.write(app_payload)
#
# print("🐍 Success! app.py has been written to your folder. Your laptop hard drive remains clean!")# Wrap the app.py payload cleanly into a string variable

# %% [raw]
# # Wrap the app.py payload cleanly into a string variable
# app_payload = """from flask import Flask
# import boto3
# from moto import mock_aws
# import os
#
# app = Flask(__name__)
#
# mock = mock_aws()
# mock.start()
#
# s3 = boto3.client("s3", region_name="us-east-1")
# BUCKET_NAME = "vehicle-diagnostic-vault"
# s3.create_bucket(Bucket=BUCKET_NAME)
#
# s3.put_object(
#     Bucket=BUCKET_NAME,
#     Key="live_fault_code.txt",
#     Body="🚨 CLOUD DATA: P0171 - System Too Lean (Bank 1)"
# )
#
# @app.route("/")
# def home():
#     # 🛠️ Swapped to single triple-quotes. Clean, readable, and zero backslashes!
#     return '''
#     <h1>🌐 Diagnostic Web Portal Active</h1>
#     <p>Welcome to the main station terminal.</p>
#     <hr>
#     <a href="/diagnostics" style="padding: 10px 15px; background-color: #007bff; color: white; text-decoration: none; border-radius: 5px; font-family: sans-serif;">
#         🚀 Launch System Diagnostics Scanner
#     </a>
#     '''
#
# @app.route("/diagnostics")
# def diagnostics():
#     response = s3.get_object(Bucket=BUCKET_NAME, Key="live_fault_code.txt")
#     cloud_data = response["Body"].read().decode("utf-8")
#
#     output_dir = "/app/output"
#     output_filepath = os.path.abspath(os.path.join(output_dir, "live_fault_code.txt"))
#
#     if not os.path.exists(output_dir):
#         os.makedirs(output_dir)
#
#     with open(output_filepath, "w") as f:
#         f.write(cloud_data)
#
#     # 🛠️ Swapped to single triple-quotes here too!
#     return f'''
#     <h2>📊 System Scan Live Feed</h2>
#     <div style="padding: 15px; background-color: #e2f0d9; color: #385723; border: 1px solid #c5e0b4; border-radius: 5px; font-family: monospace; font-size: 1.1em; margin-bottom: 15px;">
#         ✅ <strong>Cloud Match Verification:</strong> Connected to mock S3 bucket successfully.
#     </div>
#     <div style="padding: 15px; background-color: #f8d7da; color: #721c24; border: 1px solid #f5c6cb; border-radius: 5px; font-family: monospace; font-size: 1.2em;">
#         {cloud_data}
#     </div>
#     <p style="color: #2e75b6; font-family: sans-serif; font-weight: bold;">
#         💾 Local Host Sync: Copy written to container path '{output_filepath}'
#     </p>
#     <br>
#     <a href="/" style="color: #6c757d; font-family: sans-serif;">⬅️ Return to Main Terminal</a>
#     '''
#
# if __name__ == "__main__":
#     app.run(host="0.0.0.0", port=5000)
# """
#
# # Write the payload out as a python file on your laptop hard drive
# with open("app.py", "w") as f:
#     f.write(app_payload)
#
# print("🐍 Success! app.py has been written flawlessly to your folder.")

# %%
# Wrap the app.py payload cleanly into a string variable
app_payload = """from flask import Flask
import boto3
from moto import mock_aws
from pathlib import Path  # <-- Cambiado al estándar moderno

app = Flask(__name__)

mock = mock_aws()
mock.start()

s3 = boto3.client("s3", region_name="us-east-1")
BUCKET_NAME = "vehicle-diagnostic-vault"
s3.create_bucket(Bucket=BUCKET_NAME)

s3.put_object(
    Bucket=BUCKET_NAME,
    Key="live_fault_code.txt",
    Body="🚨 CLOUD DATA: P0171 - System Too Lean (Bank 1)"
)

@app.route("/")
def home():
    return '''
    <h1>🌐 Diagnostic Web Portal Active</h1>
    <p>Welcome to the main station terminal.</p>
    <hr>
    <a href="/diagnostics" style="padding: 10px 15px; background-color: #007bff; color: white; text-decoration: none; border-radius: 5px; font-family: sans-serif;">
        🚀 Launch System Diagnostics Scanner
    </a>
    '''

@app.route("/diagnostics")
def diagnostics():
    response = s3.get_object(Bucket=BUCKET_NAME, Key="live_fault_code.txt")
    cloud_data = response["Body"].read().decode("utf-8")
     
    # 🎯 SOLUCIÓN CLOUD DINÁMICA: Encuentra la ruta local actual de forma inteligente
    BASE_DIR = Path.cwd()
    output_dir = BASE_DIR / "output"
    output_filepath = output_dir / "live_fault_code.txt"
    
    # Pathlib crea la estructura de forma segura sin importar el Sistema Operativo
    output_dir.mkdir(parents=True, exist_ok=True)
        
    with open(output_filepath, "w", encoding="utf-8") as f:
        f.write(cloud_data)
        
    return f'''
    <h2>📊 System Scan Live Feed</h2>
    <div style="padding: 15px; background-color: #e2f0d9; color: #385723; border: 1px solid #c5e0b4; border-radius: 5px; font-family: monospace; font-size: 1.1em; margin-bottom: 15px;">
        ✅ <strong>Cloud Match Verification:</strong> Connected to mock S3 bucket successfully.
    </div>
    <div style="padding: 15px; background-color: #f8d7da; color: #721c24; border: 1px solid #f5c6cb; border-radius: 5px; font-family: monospace; font-size: 1.2em;">
        {cloud_data}
    </div>
    <p style="color: #2e75b6; font-family: sans-serif; font-weight: bold;">
        💾 Local Host Sync: Copy written to path '{output_filepath}'
    </p>
    <br>
    <a href="/" style="color: #6c757d; font-family: sans-serif;">⬅️ Return to Main Terminal</a>
    '''

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)
"""

# Write the payload out as a python file on your laptop hard drive
with open("app.py", "w") as f:
    f.write(app_payload)

print("🐍 Success! app.py has been updated flawlessly with Pathlib.")
# Out:
# 🐍 Success! app.py has been updated flawlessly with Pathlib.

# %%
<html><head></head><body><h1>🌐 Diagnostic Web Portal Active</h1>
    <p>Welcome to the main station terminal.</p>
    <hr>
    <a href="/diagnostics" style="padding: 10px 15px; background-color: #007bff; color: white; text-decoration: none; border-radius: 5px; font-family: sans-serif;">
        🚀 Launch System Diagnostics Scanner
    </a>
    </body></html>

# %%
# =====================================================================
# 📜 STEP 3: CONSTRUCT THE DOCKERFILE FACTORY BLUEPRINT
# =====================================================================
dockerfile_content = """# 1. Use an official, lightweight Python engine base
FROM python:3.11-slim

# 2. Establish our working workshop chamber inside the container
WORKDIR /app

# 3. Copy our tool list inventory into the container first
COPY requirements.txt .

# 4. Install the required tools inside the container chamber
RUN pip install --no-cache-dir -r requirements.txt

# 5. Copy our core machinery application payload into the container
COPY app.py .

# 6. Expose the port that our Flask web portal runs on
EXPOSE 5000

# 7. The ignition command to turn the key and start the app
CMD ["python", "app.py"]
"""

with open("Dockerfile", "w") as f:
    f.write(dockerfile_content)

print("📜 Success! Dockerfile blueprint has been written to your folder!")
# Out:
# 📜 Success! Dockerfile blueprint has been written to your folder!

# %%
# !docker build -t fleet-app-worker .
# !docker build --no-cache -t fleet-app-worker .
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.0s
# [+] Building 0.1s (3/3) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 632B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => ERROR [internal] load metadata for docker.io/library/python:3.11-slim  0.0s
# ------
#  > [internal] load metadata for docker.io/library/python:3.11-slim:
# ------
# failed to solve with frontend dockerfile.v0: failed to create LLB definition: failed to do request: Head "https://registry-1.docker.io/v2/library/python/manifests/3.11-slim": dialing registry-1.docker.io:443 static system has no HTTPS proxy: resolving host registry-1.docker.io: lookup registry-1.docker.io: no such host

# %%
# !docker run --rm -p 5000:5000 -v $(pwd)/diagnostics_output:/app/output fleet-app-worker
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.17.0.2:5000
# Press CTRL+C to quit
# 172.17.0.1 - - [17/Jun/2026 22:44:47] "GET / HTTP/1.1" 200 -
# 172.17.0.1 - - [17/Jun/2026 22:44:49] "GET /diagnostics HTTP/1.1" 200 -
# 172.17.0.1 - - [17/Jun/2026 22:45:09] "GET / HTTP/1.1" 200 -
# 172.17.0.1 - - [17/Jun/2026 22:45:11] "GET /diagnostics HTTP/1.1" 200 -
# ^C

# %%
# !docker run --rm -p 5000:5000 -v {pwd}/diagnostics_output:/app/output fleet-app-worker

# %%
# !docker run --rm -p 5000:5000 -v ./diagnostics_output:/app/output fleet-app-worker

# %%
import os
# Grab the exact absolute path of your current folder
absolute_path = os.getcwd()

print(f"Your absolute path is: {absolute_path}")

# %% [raw]
# Cloud_engineering_practice/second_container/third_version/vehicle-fault-pipeline/diagnostics_output/live_fault_code.txt

# %%
Cloud_engineering_practice/second_container/third_version/vehicle-fault-pipeline/diagnostics_output

# %%
import os
# Grab the exact absolute path of your current folder
absolute_path = os.getcwd()

print(f"Your absolute path is: {absolute_path}")

# %% [raw]
# !docker run --rm -p 5000:5000 -v /Users/admin/Desktop/Shafer_Python_Classes/Cloud_engineering_practice/second_container/third_version/vehicle-fault-pipeline/diagnostics_output:/app/output fleet-app-worker

# %%
# Wrap the app.py payload cleanly into a string variable
app_payload = """from flask import Flask
import boto3
from moto import mock_aws
import os

app = Flask(__name__)

# Initialize mock cloud storage
mock = mock_aws()
mock.start()
s3 = boto3.client("s3", region_name="us-east-1")
BUCKET_NAME = "vehicle-diagnostic-vault"
s3.create_bucket(Bucket=BUCKET_NAME)
s3.put_object(
    Bucket=BUCKET_NAME,
    Key="live_fault_code.txt",
    Body="🚨 CLOUD DATA: P0171 - System Too Lean (Bank 1)"
)

@app.route("/")
def home():
    return '''
    <h1>🌐 Diagnostic Web Portal Active</h1>
    <p>Welcome to the main station terminal.</p>
    <hr>
    <a href="/diagnostics" style="padding: 10px 15px; background-color: #007bff; color: white; text-decoration: none; border-radius: 5px; font-family: sans-serif;">
        🚀 Launch System Diagnostics Scanner & Path Analysis
    </a>
    '''

@app.route("/diagnostics")
def diagnostics():
    # 1. Fetch cloud data
    response = s3.get_object(Bucket=BUCKET_NAME, Key="live_fault_code.txt")
    cloud_data = response["Body"].read().decode("utf-8")
     
    # 2. PATH PRACTICE BLOCK (os.path.join & os.path.abspath)
    # Define the directory name and file name as individual variables
    log_dir_name = "logs"
    file_name = "app_status.txt"
    
    # Use os.path.join() to combine them safely regardless of OS architecture
    relative_file_path = os.path.join(log_dir_name, file_name)
    
    # Use os.path.abspath() to calculate the absolute system path from the root
    absolute_file_path = os.path.abspath(relative_file_path)
    absolute_dir_path = os.path.abspath(log_dir_name)
    
    # Get the location of the running script itself
    script_location = os.path.abspath(__file__)
    
    # 3. Create the directory if it doesn't exist yet
    if not os.path.exists(absolute_dir_path):
        os.makedirs(absolute_dir_path)
        
    # 4. Write the file out to the hard drive
    status_payload = f"System Scan verified by script at {script_location}. Cloud Message: {cloud_data}"
    with open(absolute_file_path, "w") as f:
        f.write(status_payload)
        
    return f'''
    <h2>📊 System Scan & Path Diagnostics</h2>
    
    <div style="background-color: #f8f9fa; border: 1px solid #dee2e6; padding: 15px; border-radius: 5px; font-family: monospace; margin-bottom: 15px;">
        <h3>🔍 Environment Path Metrics:</h3>
        <p><strong>1. Active Script Location (__file__):</strong><br> <span style="color: #d63384;">{script_location}</span></p>
        <p><strong>2. Combined Target Folder Path:</strong><br> <span style="color: #0d6efd;">{absolute_dir_path}</span></p>
        <p><strong>3. Final Absolute File Path:</strong><br> <span style="color: #198754;">{absolute_file_path}</span></p>
    </div>

    <div style="padding: 15px; background-color: #e2f0d9; color: #385723; border: 1px solid #c5e0b4; border-radius: 5px; font-family: monospace; margin-bottom: 15px;">
        📝 <strong>Written File Payload Content:</strong><br>
        <i>"{status_payload}"</i>
    </div>
    
    <a href="/" style="color: #6c757d; font-family: sans-serif;">⬅️ Return to Main Terminal</a>
    '''

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)
"""

# Write the payload out as app.py on your host machine
with open("app.py", "w") as f:
    f.write(app_payload)

print("🐍 Success! Updated app.py with path diagnostics has been written.")

# %%
# Wrap the app.py payload cleanly into a string variable
app_payload = """from flask import Flask
import boto3
from moto import mock_aws
import os

app = Flask(__name__)

# Initialize mock cloud storage
mock = mock_aws()
mock.start()
s3 = boto3.client("s3", region_name="us-east-1")
BUCKET_NAME = "vehicle-diagnostic-vault"
s3.create_bucket(Bucket=BUCKET_NAME)
s3.put_object(
    Bucket=BUCKET_NAME,
    Key="live_fault_code.txt",
    Body="🚨 CLOUD DATA: P0171 - System Too Lean (Bank 1)"
)

@app.route("/")
def home():
    return '''
    <h1>🌐 Diagnostic Web Portal Active</h1>
    <p>Welcome to the main station terminal.</p>
    <hr>
    <a href="/diagnostics" style="padding: 10px 15px; background-color: #007bff; color: white; text-decoration: none; border-radius: 5px; font-family: sans-serif;">
        🚀 Launch System Diagnostics Scanner & Path Analysis
    </a>
    '''

@app.route("/diagnostics")
def diagnostics():
    # 1. Fetch cloud data
    response = s3.get_object(Bucket=BUCKET_NAME, Key="live_fault_code.txt")
    cloud_data = response["Body"].read().decode("utf-8")
     
    # 2. PATH PRACTICE BLOCK (os.path.join & os.path.abspath)
    log_dir_name = "logs"
    file_name = "app_status.txt"
    
    # Safely combine variables into a system path
    relative_file_path = os.path.join(log_dir_name, file_name)
    
    # Calculate absolute system targets
    absolute_file_path = os.path.abspath(relative_file_path)
    absolute_dir_path = os.path.abspath(log_dir_name)
    
    # Get the location of the running script itself
    script_location = os.path.abspath(__file__)
    
    # 3. 🛠️ THE UPGRADE: Replaced the 3-line 'if' block with a single safety net
    os.makedirs(absolute_dir_path, exist_ok=True)
        
    # 4. Write the file out to the hard drive
    status_payload = f"System Scan verified by script at {script_location}. Cloud Message: {cloud_data}"
    with open(absolute_file_path, "w") as f:
        f.write(status_payload)
        
    return f'''
    <h2>📊 System Scan & Path Diagnostics</h2>
    
    <div style="background-color: #f8f9fa; border: 1px solid #dee2e6; padding: 15px; border-radius: 5px; font-family: monospace; margin-bottom: 15px;">
        <h3>🔍 Environment Path Metrics:</h3>
        <p><strong>1. Active Script Location (__file__):</strong><br> <span style="color: #d63384;">{script_location}</span></p>
        <p><strong>2. Combined Target Folder Path:</strong><br> <span style="color: #0d6efd;">{absolute_dir_path}</span></p>
        <p><strong>3. Final Absolute File Path:</strong><br> <span style="color: #198754;">{absolute_file_path}</span></p>
    </div>

    <div style="padding: 15px; background-color: #e2f0d9; color: #385723; border: 1px solid #c5e0b4; border-radius: 5px; font-family: monospace; margin-bottom: 15px;">
        📝 <strong>Written File Payload Content:</strong><br>
        <i>"{status_payload}"</i>
    </div>
    
    <a href="/" style="color: #6c757d; font-family: sans-serif;">⬅️ Return to Main Terminal</a>
    '''

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)
"""

# Write the payload out as app.py on your host machine
with open("app.py", "w") as f:
    f.write(app_payload)

print("🐍 Success! app.py has been written using the clean exist_ok=True parameter.")

# %%
# !pip install flask boto3 moto
# Out:
# Requirement already satisfied: flask in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (3.1.3)
# Requirement already satisfied: boto3 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (1.43.22)
# Requirement already satisfied: moto in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (5.2.1)
# Requirement already satisfied: blinker>=1.9.0 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from flask) (8.1.7)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from flask) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from flask) (2.1.5)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from flask) (3.1.8)
# Requirement already satisfied: botocore<1.44.0,>=1.43.22 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from boto3) (1.43.22)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.19.0,>=0.18.0 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from boto3) (0.18.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from botocore<1.44.0,>=1.43.22->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from botocore<1.44.0,>=1.43.22->boto3) (2.2.2)
# Requirement already satisfied: six>=1.5 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.22->boto3) (1.16.0)
# Requirement already satisfied: cryptography>=35.0.0 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from moto) (48.0.0)
# Requirement already satisfied: requests>=2.5 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from moto) (2.32.5)
# Requirement already satisfied: xmltodict in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from moto) (1.0.4)
# Requirement already satisfied: responses!=0.25.5,>=0.15.0 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from moto) (0.26.1)
# Requirement already satisfied: cffi>=2.0.0 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from cryptography>=35.0.0->moto) (2.0.0)
# Requirement already satisfied: pycparser in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=35.0.0->moto) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from requests>=2.5->moto) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from requests>=2.5->moto) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from requests>=2.5->moto) (2024.6.2)
# Requirement already satisfied: pyyaml in /Users/admin/Desktop/Shafer_Python_Classes/pandas_env/lib/python3.11/site-packages (from responses!=0.25.5,>=0.15.0->moto) (6.0.1)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !python app.py
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.20.10.3:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/Jun/2026 16:00:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2026 16:00:54] "GET /diagnostics HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Jun/2026 16:01:04] "GET / HTTP/1.1" 200 -
# ^C

# %%
# !docker build --no-cache -t fleet-path-analyzer .

# %%
# !docker build --no-cache -t fleet-path-analyzer .

# %%
# !pwd

# %%
# !ls -la

# %%
requirements_payload = """flask
boto3
moto"""

with open("requirements.txt", "w") as f:
    f.write(requirements_payload)

print("📝 requirements.txt has been dropped into the folder!")

# %%
dockerfile_payload = """FROM python:3.10-slim
WORKDIR /app
COPY requirements.txt .
RUN pip install --no-cache-dir -r requirements.txt
COPY app.py .
EXPOSE 5000
CMD ["python", "app.py"]"""

with open("Dockerfile", "w") as f:
    f.write(dockerfile_payload)

print("🐳 Dockerfile blueprint has been dropped into the folder!")

# %%
# !docker build --no-cache -t fleet-path-analyzer .

# %%
# !docker run --rm -p 5000:5000 -v $(pwd)/diagnostics_output:/app/logs fleet-path-analyzer
